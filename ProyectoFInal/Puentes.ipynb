# %% [markdown]
# <table>
#     <tr>
#         <td><img src="./img/Macc.png" width="min"/></td>
#         <td>
#             <table><tr>
#             <h1 style="color:blue;text-align:center">Lógica para Ciencias de la Computación</h1></td>
#             </tr></table>
#         <td>&nbsp;</td>
#         <td>
#             <table><tr>
#             <tp><p style="font-size:150%;text-align:center">Proyecto Final</p></tp>
#             <tp><p style="font-size:150%;text-align:center">Puentes de Königsberg</p></tp>
#             </tr></table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # Objetivos <a class="anchor" id="inicio"></a>
#
# En este notebook se irá describiendo el paso a paso de la solución para los puentes de Konigsberg, el objetivo principal es encontrar al menos una fórmula en la que sea realizable el ejercicio. Dado el mapa de Königsberg, el río Prägel, que divide el plano en cuatro regiones distintas conectadas por siete puentes. Se quiere demostrar que camino(s) son posibles, comenzando a caminar desde cualquiera de estas regiones cruzando todos los puentes una sola vez y volviendo al mismo punto de partida.

# %% [markdown]
# # ¿Qué sucede en los puentes de  Königsberg? <a class="anchor" id="sat"></a>
#
#  El problema se formuló en el siglo XVIII y consistía en encontrar un recorrido para cruzar a pie toda la ciudad pasando solo una vez por cada uno de los puentes y regresando al mismo punto de inicio.
#
# Después de varios ensayos e investigación llegamos a resolver que es algo imposible, es necesario cruzar algún puente más de una vez. A base de repetir y repetir acabamos dándonos cuenta de que es un problema irresoluble. Ya que no existía ninguna manera en que se pudiesen atravesar los 7 puentes originales.
#
# <img src="./img/puentes_original.png" width="auto"/>
#
# A lo que, decidimos reducir la cantidad total de puentes a 5. Dando como esquema algo similar a lo siguiente:
#
# <img src="./img/hacible.jpeg" width="auto"/>

# %%
#importar librerias
import Logica
import random

# %% [markdown]
# # Reglas <a class="anchor" id="reglas"></a>
#
# 1. Se debe pasar por los cinco puentes.
# 2. No se puede pasar dos veces por el mismo puente.
# 3. Se inicia en la región A y se termina en la región D.
# 4. Conexión.
#
#
# 1. programar las reglas
# Se hará por profundidad primero

# %% [markdown]
# # Regla 1
# $$ \bigwedge_{{i}\in\texttt{T}} (p_i \vee q_i) \wedge \bigwedge_{{i}\in\texttt{T}} (s_i \vee r_i) \wedge \bigwedge_{{i}\in\texttt{T}}(u_i \vee t_i) \wedge \bigwedge_{{i}\in\texttt{T}}(y_i \vee x_i) \wedge \bigwedge_{{i}\in\texttt{T}}(b_i \vee c_i)

# %%
#Regla 1
l_p = {"p": None, "q":None , "r":None, "s":None, "t":None, "u":None, "x":None,
       "y":None, 'b':None, 'c':None}
T = [1, 2, 3, 4, 5]
p1 = ["p", "q"]
r1 = random.choice(p1)
if r1 == "p":
    l_p['p'] = True
    l_p['q'] = False
else:
    l_p['q'] = True 
    l_p["p"] = False

p2 = ["s", "r"]
r2 = random.choice(p2)
if r2 == "s":
    l_p['s'] = True
    l_p['r'] = False
else: 
    l_p['r'] = True
    l_p["s"] = False
    
p3 = ["u", "t"]
r3 = random.choice(p3)
if r3 == "u":
    l_p['u'] = True
    l_p['t'] = False
else: 
    l_p['t'] = True
    l_p["u"] = False

p4= ["y", "x"]
r4 = random.choice(p4)
if r4 == "y":
    l_p['y'] = True
    l_p['x'] = False
else: 
    l_p['x'] = True
    l_p["y"] = False

p5 = ["b", "c"]
r5 = random.choice(p5)
if r5 == "b":
    l_p['b'] = True
    l_p['c'] = False
else: 
    l_p['c'] = True
    l_p["b"] = False
    
print(l_p)
""""
def regla1(inter):
    lista_camino = []
    for i in inter:
        if i.values == True:
             lista_camino.append(i.key)
        else:
             pass
    return(lista_camino)

prueba1 = regla1(l_p)
print(prueba1)
    #lista_camino = []
    #for i in l_p:
    #    if i == True:
    #        lista_camino.append(i)
    #return lista_camino            
"""
'''puentes = (r1, r2, r3, r4, r5)
def regla1(puentes,T):
    interpre = []
    c = 0
    for i in range(len(T)):
        interpre.append'''
# Out:
# {'p': False, 'q': True, 'r': False, 's': True, 't': True, 'u': False, 'x': False, 'y': True, 'b': False, 'c': True}
# 'puentes = (r1, r2, r3, r4, r5)\ndef regla1(puentes,T):\n    interpre = []\n    c = 0\n    for i in range(len(T)):\n        interpre.append'

# %%
puentes = [r1, r2, r3, r4, r5]

def regla1(puentes, T):
    inter = []
    contador = 1
    for t in T:
        for puente in puentes:
            #print(puente)
            inter.append(puente)
        #print("En el turno {0} está el sentido {1}: ".format(t, puente))
    for sentido in inter:
            for t in T:
                print("En el turno {0} está el sentido {1} {2}".format(t, sentido,contador))
                contador += 1

regla1(puentes,T)
# Out:
# En el turno 1 está el sentido q 1
# En el turno 2 está el sentido q 2
# En el turno 3 está el sentido q 3
# En el turno 4 está el sentido q 4
# En el turno 5 está el sentido q 5
# En el turno 1 está el sentido s 6
# En el turno 2 está el sentido s 7
# En el turno 3 está el sentido s 8
# En el turno 4 está el sentido s 9
# En el turno 5 está el sentido s 10
# En el turno 1 está el sentido t 11
# En el turno 2 está el sentido t 12
# En el turno 3 está el sentido t 13
# En el turno 4 está el sentido t 14
# En el turno 5 está el sentido t 15
# En el turno 1 está el sentido y 16
# En el turno 2 está el sentido y 17
# En el turno 3 está el sentido y 18
# En el turno 4 está el sentido y 19
# En el turno 5 está el sentido y 20
# En el turno 1 está el sentido c 21
# En el turno 2 está el sentido c 22
# En el turno 3 está el sentido c 23
# En el turno 4 está el sentido c 24
# En el turno 5 está el sentido c 25
# En el turno 1 está el sentido q 26
# En el turno 2 está el sentido q 27
# En el turno 3 está el sentido q 28
# En el turno 4 está el sentido q 29
# En el turno 5 está el sentido q 30
# En el turno 1 está el sentido s 31
# En el turno 2 está el sentido s 32
# En el turno 3 está el sentido s 33
# En el turno 4 está el sentido s 34
# En el turno 5 está el sentido s 35
# En el turno 1 está el sentido t 36
# En el turno 2 está el sentido t 37
# En el turno 3 está el sentido t 38
# En el turno 4 está el sentido t 39
# En el turno 5 está el sentido t 40
# En el turno 1 está el sentido y 41
# En el turno 2 está el sentido y 42
# En el turno 3 está el sentido y 43
# En el turno 4 está el sentido y 44
# En el turno 5 está el sentido y 45
# En el turno 1 está el sentido c 46
# En el turno 2 está el sentido c 47
# En el turno 3 está el sentido c 48
# En el turno 4 está el sentido c 49
# En el turno 5 está el sentido c 50
# En el turno 1 está el sentido q 51
# En el turno 2 está el sentido q 52
# En el turno 3 está el sentido q 53
# En el turno 4 está el sentido q 54
# En el turno 5 está el sentido q 55
# En el turno 1 está el sentido s 56
# En el turno 2 está el sentido s 57
# En el turno 3 está el sentido s 58
# En el turno 4 está el sentido s 59
# En el turno 5 está el sentido s 60
# En el turno 1 está el sentido t 61
# En el turno 2 está el sentido t 62
# En el turno 3 está el sentido t 63
# En el turno 4 está el sentido t 64
# En el turno 5 está el sentido t 65
# En el turno 1 está el sentido y 66
# En el turno 2 está el sentido y 67
# En el turno 3 está el sentido y 68
# En el turno 4 está el sentido y 69
# En el turno 5 está el sentido y 70
# En el turno 1 está el sentido c 71
# En el turno 2 está el sentido c 72
# En el turno 3 está el sentido c 73
# En el turno 4 está el sentido c 74
# En el turno 5 está el sentido c 75
# En el turno 1 está el sentido q 76
# En el turno 2 está el sentido q 77
# En el turno 3 está el sentido q 78
# En el turno 4 está el sentido q 79
# En el turno 5 está el sentido q 80
# En el turno 1 está el sentido s 81
# En el turno 2 está el sentido s 82
# En el turno 3 está el sentido s 83
# En el turno 4 está el sentido s 84
# En el turno 5 está el sentido s 85
# En el turno 1 está el sentido t 86
# En el turno 2 está el sentido t 87
# En el turno 3 está el sentido t 88
# En el turno 4 está el sentido t 89
# En el turno 5 está el sentido t 90
# En el turno 1 está el sentido y 91
# En el turno 2 está el sentido y 92
# En el turno 3 está el sentido y 93
# En el turno 4 está el sentido y 94
# En el turno 5 está el sentido y 95
# En el turno 1 está el sentido c 96
# En el turno 2 está el sentido c 97
# En el turno 3 está el sentido c 98
# En el turno 4 está el sentido c 99
# En el turno 5 está el sentido c 100
# En el turno 1 está el sentido q 101
# En el turno 2 está el sentido q 102
# En el turno 3 está el sentido q 103
# En el turno 4 está el sentido q 104
# En el turno 5 está el sentido q 105
# En el turno 1 está el sentido s 106
# En el turno 2 está el sentido s 107
# En el turno 3 está el sentido s 108
# En el turno 4 está el sentido s 109
# En el turno 5 está el sentido s 110
# En el turno 1 está el sentido t 111
# En el turno 2 está el sentido t 112
# En el turno 3 está el sentido t 113
# En el turno 4 está el sentido t 114
# En el turno 5 está el sentido t 115
# En el turno 1 está el sentido y 116
# En el turno 2 está el sentido y 117
# En el turno 3 está el sentido y 118
# En el turno 4 está el sentido y 119
# En el turno 5 está el sentido y 120
# En el turno 1 está el sentido c 121
# En el turno 2 está el sentido c 122
# En el turno 3 está el sentido c 123
# En el turno 4 está el sentido c 124
# En el turno 5 está el sentido c 125

# %%
puentes = [r1, r2, r3, r4, r5]

def regla1(puentes, T):
    inter = []
    for t in T:
        rand = random.choice(puentes)
        inter.append(rand)
        print("En el turno {0} está el sentido {1}: ".format(t, inter))
        inter.pop()
    
regla1(puentes,T)
# Out:
# En el turno 1 está el sentido ['s']:
# En el turno 2 está el sentido ['s']:
# En el turno 3 está el sentido ['y']:
# En el turno 4 está el sentido ['y']:
# En el turno 5 está el sentido ['s']:

# %% [markdown]
# # Regla 2
#
# $$ \left(\bigvee_{{i}\in\texttt{T}} (p_i \to \bigwedge_{{j}\in\texttt{T}} \neg p_j \wedge \neg q_j) \vee
# \bigvee_{{i}\in\texttt{T}} (q_i \to \bigwedge_{{j}\in\texttt{T}} \neg q_j \wedge \neg p_j)\right) \vee
# \left(\bigvee_{{i}\in\texttt{T}} (s_i \to \bigwedge_{{j}\in\texttt{T}} \neg s_j \wedge \neg r_i) \vee
# \bigvee_{{i}\in\texttt{T}} (r_i \to \bigwedge_{{j}\in\texttt{T}} \neg r_j \wedge \neg s_j)\right) \vee
# \left(\bigvee_{{i}\in\texttt{T}} (u_i \to \bigwedge_{{j}\in\texttt{T}} \neg u_j \wedge \neg t_j) \vee
# \bigvee_{{i}\in\texttt{T}} (t_i \to \bigwedge_{{j}\in\texttt{T}} \neg t_j \wedge \neg u_j)\right) \vee

# %% [markdown]
# $$ \left(\bigvee_{{i}\in\texttt{T}} (y_i \to \bigwedge_{{j}\in\texttt{T}} \neg y_j \wedge \neg x_j) \vee
# \bigvee_{{i}\in\texttt{T}} (x_i \to \bigwedge_{{j}\in\texttt{T}} \neg x_j \wedge \neg y_j)\right) \vee
# \left(\bigvee_{{i}\in\texttt{T}} (b_i \to \bigwedge_{{j}\in\texttt{T}} \neg b_j \wedge \neg c_j) \vee
# \bigvee_{{i}\in\texttt{T}} (c_i \to \bigwedge_{{j}\in\texttt{T}} \neg c_j \wedge \neg b_j)\right)

# %%
#Regla 2
l_p = {"p": None, "q":None , "r":None, "s":None, "t":None, "u":None, "x":None,
       "y":None, 'b':None, 'c':None}

puente1 = [("p", T[0]), ("q", T[0])]
opc1 = random.choice(puente1)
print("La letra que escogio es:",opc1)

puente2 = [("s", T[0]), ("r", T[0])]
opc2 = random.choice(puente2)
print("La letra que escogio es:",opc2)

puente3 = [("u", T[0]), ("t", T[0])]
opc3 = random.choice(puente3)
print("La letra que escogio es:",opc3)

puente4 = [("y", T[0]), ("x", T[0])]
opc4 = random.choice(puente4)
print("La letra que escogio es:",opc4)

puente5 = [("b", T[0]), ("c", T[0])]
opc5 = random.choice(puente5)
print("La letra que escogio es:",opc5)
             
#Puente 1
print()
print("Puente 1")
if opc1 == ("p",T[0]):
    l_p["p"] = True
    l_p["q"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["p"] = False
            l_p["q"] = False
            print("Turno 2")
            print(l_p)
else: #opc1 == ("q",T[0])
    l_p["q"] = True
    l_p["p"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["p"] = False
            l_p["q"] = False
            print("Turno 2")
            print(l_p)
    


#Puente 2
print()
print("Puente 2")
if opc2 == ("s",T[0]):
    l_p["s"] = True
    l_p["r"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["s"] = False
            l_p["r"] = False
            print("Turno 2")
            print(l_p)
elif opc2 == ("r",T[0]):
    l_p["r"] = True
    l_p["s"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["r"] = False
            l_p["s"] = False
            print("Turno 2")
            print(l_p)

#Puente 3
print()
print("Puente 3")
if opc3 == ("u",T[0]):
    l_p["u"] = True
    l_p["t"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["u"] = False
            l_p["t"] = False
            print("Turno 2")
            print(l_p)
elif opc3 == ("t",T[0]):
    l_p["t"] = True
    l_p["u"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["u"] = False
            l_p["t"] = False
            print("Turno 2")
            print(l_p)

#Puente 4
print()
print("Puente 4")
if opc4 == ("y",T[0]):
    l_p["y"] = True
    l_p["x"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["y"] = False
            l_p["x"] = False
            print("Turno 2")
            print(l_p)
elif opc4 == ("x",T[0]):
    l_p["x"] = True
    l_p["y"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["y"] = False
            l_p["x"] = False
            print("Turno 2")
            print(l_p)

#Puente 5
print()
print("Puente 5")
if opc5 == ("b",T[0]):
    l_p["b"] = True
    l_p["c"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["b"] = False
            l_p["c"] = False
            print("Turno 2")
            print(l_p)
elif opc5 == ("c",T[0]):
    l_p["c"] = True
    l_p["b"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["b"] = False
            l_p["c"] = False
            print("Turno 2")
            print(l_p)

#la l indica el numero del turno.
# Out:
# La letra que escogio es: ('p', 1)
# La letra que escogio es: ('r', 1)
# La letra que escogio es: ('t', 1)
# La letra que escogio es: ('x', 1)
# La letra que escogio es: ('b', 1)
#
# Puente 1
# Turno 1
# {'p': True, 'q': False, 'r': None, 's': None, 't': None, 'u': None, 'x': None, 'y': None, 'b': None, 'c': None}
# Turno 2
# {'p': False, 'q': False, 'r': None, 's': None, 't': None, 'u': None, 'x': None, 'y': None, 'b': None, 'c': None}
#
# Puente 2
# Turno 1
# {'p': False, 'q': False, 'r': True, 's': False, 't': None, 'u': None, 'x': None, 'y': None, 'b': None, 'c': None}
# Turno 2
# {'p': False, 'q': False, 'r': False, 's': False, 't': None, 'u': None, 'x': None, 'y': None, 'b': None, 'c': None}
#
# Puente 3
# Turno 1
# {'p': False, 'q': False, 'r': False, 's': False, 't': True, 'u': False, 'x': None, 'y': None, 'b': None, 'c': None}
# Turno 2
# {'p': False, 'q': False, 'r': False, 's': False, 't': False, 'u': False, 'x': None, 'y': None, 'b': None, 'c': None}
#
# Puente 4
# Turno 1
# {'p': False, 'q': False, 'r': False, 's': False, 't': False, 'u': False, 'x': True, 'y': False, 'b': None, 'c': None}
# Turno 2
# {'p': False, 'q': False, 'r': False, 's': False, 't': False, 'u': False, 'x': False, 'y': False, 'b': None, 'c': None}
#
# Puente 5
# Turno 1
# {'p': False, 'q': False, 'r': False, 's': False, 't': False, 'u': False, 'x': False, 'y': False, 'b': True, 'c': False}
# Turno 2
# {'p': False, 'q': False, 'r': False, 's': False, 't': False, 'u': False, 'x': False, 'y': False, 'b': False, 'c': False}

# %% [markdown]
# # Regla 3:
# $$(p_{1} \vee r_{1}\vee b_{1}) \wedge (u_{5} \vee s_{5} \vee y_{5})  $$

# %%
def regla3():
    salidas = ("p","y","b")
    inicial = (random.choice(salidas), T[0])
    if inicial == "y":
        n_entradas = ('u', 's')
        final = (random.choice(n_entradas), T[-1])
        
    else:
        n_entradas = ("u","s","y")
        final = (random.choice(n_entradas), T[-1])
    print("Empieza en:",inicial, "y acaba en:",final)

#regla3()

# %%
#puente  (A-C)
inter1 = {"p": True, "q":False , "r":False, "s":True, "t":False, "u":True, "x":True,
       "y":False, 'b':True, 'c':False}
inter2 = {"p": True, "q":False , "r":False, "s":True, "t":True, "u":False, "x":False,
       "y":True, 'b':False, 'c':True}
#puente (A_D)
inter3 = {"p": False, "q":True , "r":True, "s":False, "t":False, "u":True, "x":False,
       "y":True, 'b':True, 'c':False}
inter4 = {"p": True, "q":False , "r":False, "s":True, "t":False, "u":True, "x":True,
       "y":False, 'b':False, 'c':True}
#puente (A-B)
inter5 = {"p": True, "q":False , "r":False, "s":True, "t":False, "u":True, "x":True,
       "y":False, 'b':True, 'c':False}
inter6 = {"p": False, "q":True , "r":True, "s":False, "t":False, "u":True, "x":False,
       "y":True, 'b':True, 'c':False}

#MAPA GENERAL
"""
print("\                                                                              /")
print(" \                                                                            /")
print("  \_____     /\    __________________________________________    /\    _____/")
print("        \    |    /                                          \    |   /")
print("        |    |    |                                          |    |   |")
print("        |    |    |                                          |    |   |")
print("        |    |    |                                          |    |   |")
print("        |    |    |                                          |    |   |")
print("   _____/    \/   \__________                      __________/   \/   \_____ ")
print("  |                          |                    |                         |")
print("  |                          |                    |                         |")
print("  |                          |____________________|                         |")
print("  |                                                                         |")
print("  |                        <------------------------>                       |")
print("  |                                                                         |")
print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
print("  |                          |                    |                         |")
print("  |_____    /\     __________|                    |__________    /\    _____|")
print("        \    |    /                                          \    |   /")
print("        |    |    |                                          |    |   |")
print("        |    |    |                                          |    |   |")
print("        |    |    |                                          |    |   |")
print("        |    |    |                                          |    |   |")
print("   _____/   \/    \__________________________________________/   \/   \_____ ")
print("  /                                                                         \ ")
print(" /                                                                           \ ")
print("/                                                                             \ ")
"""

def interpretacion1():
    print("\                                                                              /")
    print(" \                                                                            /")
    print("  \_____     /\    __________________________________________          _____/")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/         \__________                      __________/   \/   \_____ ")
    print("  |                          |                    |                         |")
    print("  |                          |                    |                         |")
    print("  |                          |____________________|                         |")
    print("  |                                                                         |")
    print("  |                        <------------------------                        |")
    print("  |                                                                         |")
    print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
    print("  |                          |                    |                         |")
    print("  |_____           __________|                    |__________    /\    _____|")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/   \/    \__________________________________________/        \_____ ")
    print("  /                                                                         \ ")
    print(" /                                                                           \ ")
    print("/                                                                             \ ")

def interpretacion2():
    print("\                                                                              /")
    print(" \                                                                            /")
    print("  \_____     /\    __________________________________________          _____/")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/         \__________                      __________/   \/   \_____ ")
    print("  |                          |                    |                         |")
    print("  |                          |                    |                         |")
    print("  |                          |____________________|                         |")
    print("  |                                                                         |")
    print("  |                        ------------------------>                        |")
    print("  |                                                                         |")
    print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
    print("  |                          |                    |                         |")
    print("  |_____     /\    __________|                    |__________          _____|")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/         \__________________________________________/   \/    \_____ ")
    print("  /                                                                         \ ")
    print(" /                                                                           \ ")
    print("/                                                                             \ ")

def interpretacion3():
    print("\                                                                              /")
    print(" \                                                                            /")
    print("  \_____           __________________________________________    /\    _____/")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/    \/   \__________                      __________/        \_____ ")
    print("  |                          |                    |                         |")
    print("  |                          |                    |                         |")
    print("  |                          |____________________|                         |")
    print("  |                                                                         |")
    print("  |                         ------------------------>                       |")
    print("  |                                                                         |")
    print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
    print("  |                          |                    |                         |")
    print("  |_____           __________|                    |__________    /\    _____|")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/   \/    \__________________________________________/        \_____ ")
    print("  /                                                                         \ ")
    print(" /                                                                           \ ")
    print("/                                                                             \ ")


def interpretacion4():
    print("\                                                                              /")
    print(" \                                                                            /")
    print("  \_____     /\    __________________________________________     2     _____/")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/    1    \__________                      __________/   \/   \_____ ")
    print("  |                          |                    |                         |")
    print("  |                          |                    |                         |")
    print("  |                          |____________________|                         |")
    print("  |                                                                         |")
    print("  |                        5 ----------------------->                       |")
    print("  |                                                                         |")
    print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
    print("  |                          |                    |                         |")
    print("  |_____    /\     __________|                    |__________     3    _____|")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/    4    \__________________________________________/   \/   \_____ ")
    print("  /                                                                         \ ")
    print(" /                                                                           \ ")
    print("/                                                                             \ ")


def interpretacion5():
    print("\                                                                              /")
    print(" \                                                                            /")
    print("  \_____     /\    __________________________________________     5    _____/")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/    4    \__________                      __________/   \/   \_____ ")
    print("  |                          |                    |                         |")
    print("  |                          |                    |                         |")
    print("  |                          |____________________|                         |")
    print("  |                                                                         |")
    print("  |                        <----------------------- 3                       |")
    print("  |                                                                         |")
    print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
    print("  |                          |                    |                         |")
    print("  |_____     1     __________|                    |__________    /\    _____|")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/   \/    \__________________________________________/    2   \_____ ")
    print("  /                                                                         \ ")
    print(" /                                                                           \ ")
    print("/                                                                             \ ")

def interpretacion6():
    print("\                                                                              /")
    print(" \                                                                            /")
    print("  \_____     4     __________________________________________    /\    _____/")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/    \/     \________                      __________/    3   \_____ ")
    print("  |                          |                    |                         |")
    print("  |                          |                    |                         |")
    print("  |                          |____________________|                         |")
    print("  |                                                                         |")
    print("  |                        5 ---------------------->                        |")
    print("  |                                                                         |")
    print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
    print("  |                          |                    |                         |")
    print("  |_____           __________|                    |__________    /\    _____|")
    print("        \    1    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/   \/    \__________________________________________/    2   \_____ ")
    print("  /                                                                         \ ")
    print(" /                                                                           \ ")
    print("/                                                                             \ ")


#



#interpretacion1() 
#interpretacion2()
#interpretacion3()
#interpretacion4()
#interpretacion5()
#interpretacion6()

# %% [markdown]
# # Regla 4
# $$ \bigvee_{{i}\in\texttt{T-5}} (p_i \to s_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} y_i \to (r_{i+1} \vee t_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} (b_i \to u_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} q_i \to (y_{i+1} \vee b_{i+1}) \wedge  \bigvee_{{i}\in\texttt{T-5}} c_i \to (y_{i+1} \vee p_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} x_i \to (p_{i+1} \vee b_{i+1}) \wedge

# %% [markdown]
# $$ \bigvee_{{i}\in\texttt{T-5}} s_i \to (x_{i+1} \vee t_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} (r_i \to q_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} u_i \to (x_{i+1} \vee r_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} (t_i \to c_{i+1})

# %%
#Regla 4
l_p = {"p": None, "q":None , "r":None, "s":None, "t":None, "u":None, "x":None,
       "y":None, 'b':None, 'c':None}
puentes = [("p", T[0]), ("q", T[0]), ("s",T[0]), ("r", T[0]), ("u", T[0]), ("t", T[0]), ("y", T[0]), ("x", T[0]), ("b", T[0]), ("c", T[0])]
opc = random.choice(puentes)
print("La letra que escogio es:",opc)


if opc == ("p", T[0]):
    l_p["p"] = True
    l_p["q"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["p"] = False
            l_p["s"] = True
            print("turno 2")
            print(l_p)

if opc == ("q", T[0]):
    l_p["q"] = True
    l_p["p"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            camino = [("y", T[1]), ("b", T[1])]
            camino_escogido = random.choice(camino)
            if camino_escogido == ("y", T[1]):
                l_p["q"] = False
                l_p["y"] = True
                print("turno 2")
                print(l_p)
            elif camino_escogido == ("b", T[1]):
                l_p["q"] = False
                l_p["b"] = True
                print("turno 2")
                print(l_p)

if opc == ("s", T[0]):
    l_p["s"] = True
    l_p["r"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            camino = [("x", T[1]), ("t", T[1])]
            camino_escogido = random.choice(camino)
            if camino_escogido == ("x", T[1]):
                l_p["s"] = False
                l_p["x"] = True
                print("turno 2")
                print(l_p)
            elif camino_escogido == ("t", T[1]):
                l_p["s"] = False
                l_p["t"] = True
                print("turno 2")
                print(l_p)

if opc == ("r", T[0]):
    l_p["r"] = True
    l_p["s"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["r"] = False
            l_p["q"] = True
            print("turno 2")
            print(l_p)

if opc == ("u", T[0]):
    l_p["u"] = True
    l_p["t"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            camino = [("x", T[1]), ("r", T[1])]
            camino_escogido = random.choice(camino)
            if camino_escogido == ("x", T[1]):
                l_p["u"] = False
                l_p["x"] = True
                print("turno 2")
                print(l_p)
            elif camino_escogido == ("r", T[1]):
                l_p["u"] = False
                l_p["r"] = True
                print("turno 2")
                print(l_p)

if opc == ("t", T[0]):
    l_p["t"] = True
    l_p["u"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["t"] = False
            l_p["c"] = True
            print("turno 2")
            print(l_p)

if opc == ("y", T[0]):
    l_p["y"] = True
    l_p["x"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            camino = [("t", T[1]), ("r", T[1])]
            camino_escogido = random.choice(camino)
            if camino_escogido == ("t", T[1]):
                l_p["y"] = False
                l_p["t"] = True
                print("turno 2")
                print(l_p)
            elif camino_escogido == ("r", T[1]):
                l_p["y"] = False
                l_p["r"] = True
                print("turno 2")
                print(l_p)

if opc == ("x", T[0]):
    l_p["x"] = True
    l_p["y"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            camino = [("p", T[1]), ("b", T[1])]
            camino_escogido = random.choice(camino)
            if camino_escogido == ("p", T[1]):
                l_p["x"] = False
                l_p["p"] = True
                print("turno 2")
                print(l_p)
            elif camino_escogido == ("b", T[1]):
                l_p["x"] = False
                l_p["b"] = True
                print("turno 2")
                print(l_p)

if opc == ("c", T[0]):
    l_p["c"] = True
    l_p["b"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            camino = [("y", T[1]), ("p", T[1])]
            camino_escogido = random.choice(camino)
            if camino_escogido == ("y", T[1]):
                l_p["c"] = False
                l_p["y"] = True
                print("turno 2")
                print(l_p)
            elif camino_escogido == ("p", T[1]):
                l_p["c"] = False
                l_p["p"] = True
                print("turno 2")
                print(l_p)

if opc == ("b", T[0]):
    l_p["b"] = True
    l_p["c"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["b"] = False
            l_p["u"] = True
            print("turno 2")
            print(l_p)
# Out:
# La letra que escogio es: ('u', 1)
# turno 1
# {'p': None, 'q': None, 'r': None, 's': None, 't': False, 'u': True, 'x': None, 'y': None, 'b': None, 'c': None}
# turno 2
# {'p': None, 'q': None, 'r': True, 's': None, 't': False, 'u': False, 'x': None, 'y': None, 'b': None, 'c': None}

# %%
#print("Si comienza en", inicial, "entonces termina en", final )
# Out:
# Empieza en: ('y', 1) y acaba en: ('s', 5)
